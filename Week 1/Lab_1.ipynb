# %% [markdown]
# <div style="font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, 'Helvetica Neue', Arial; padding: 20px; border-radius: 16px; box-shadow: 0 10px 25px rgba(0,0,0,.08); background: linear-gradient(135deg,#fff 0%, #f0f7ff 60%, #e8fff4 100%);">
#   <h1 style="margin:0 0 8px; font-size: 2rem;">
#     👋 Welcome to Math 105 Lab 1!
#   </h1>
# <div style="text-align: center; font-size: 1.5rem; font-weight: bold; margin: 20px 0;">
#   ✨This is a Jupyter notebook✨
# </div>
#
#   <div style="margin-top:16px; padding:12px 14px; border:1px dashed #94a3b8; border-radius:12px; background:#fff;">
#     <strong>Today’s mission:</strong> Familiarize ourselves with Jupyter notebooks, python code, and start thinking about functions.</div>
#
#   <div style="margin-top:14p

# %% [markdown]
# This is a Markdown cell.
#
# -We use markdown cells to communicate our thinking using words and symbols.
#
# -We can also be a little fancy and write math! For example,
#  $$f(x) = x^2, \pi, \sqrt{2}$$

# %% [markdown]
# Exercise 1: You try it!
#
# Write your name here:
#
# Write your favorite function here in math mode:

# %%
#this is a code cell
#when I begin the line with a hashtag, the computer ignores the text
#we call this a comment
#Exercise 2: Your first program. 
#the next line wont start with #, hit play and see what happens
value1 = 2 #this is a variable with assigned value 2
value2 = 1 #this is a variable with assigned value 1

total = value1+value2 #this is a variable with assigned value of the sum

print("The toal is:", total)# this is a print statement

#Exercise 3: You try it
#change the values of value1 and value2 so the total is 11. Then print the new total.

# %% [markdown]
# One main focus of today is learning how to plot data. We will be doing it a lot in this class!

# %%
#Exercise 4
# Import the plotting library
import matplotlib.pyplot as plt

# Enter the data
year = [???]

avg_price = [???]

adjusted_price = [???]

# Create the graph
plt.figure(figsize=(8, 5))

# Plot both sets of data, change these!
plt.scatter(input,output1)
plt.scatter(input,output2)

# Add labels and a title
plt.xlabel("Year")
plt.ylabel("Price ($)")
plt.title("Egg Prices Over Time")

# %% [markdown]
# Do we like how this looks? Does it communicate effectively? What should we change?

# %%
#Exercise 5
#we will write some new code here to make a better plot

# %% [markdown]
# Another thing we'll start working with is functions in Python.
#
# Just like mathematical functions, function in Python take and input and follow a rule (or set of rules) to generate an output. There is special syntax we must use to tell the computer we are making a function.
#
# The first example is $\texttt{lambda}$ functions.

# %%
#AvgPrice(t) = 0.041t−80.2
#the next line uses the keyword lambda to define the function
AvgPrice = lambda t: 0.041*t - 80.2
#now we can call the function on a given input
AvgPrice(1980)

# %%
#Exercise 6 use the lambda function for average price to fill in the rest of the table

# %%
#Exercise 7 write a lambda function for the inflation price model
#and use it to fill in the rest of the table

# %%
#Exercise 8: we will make a plot of the models together with the data. MBK will help!

# %%
#Exercise 9: complete exercise 1.4.3 from the guided notes using lambda functions in Python!

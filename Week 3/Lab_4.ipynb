# %% [markdown]
# <div style="font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, 'Helvetica Neue', Arial; padding: 20px; border-radius: 16px; box-shadow: 0 10px 25px rgba(0,0,0,.08); background: linear-gradient(135deg,#fff 0%, #f0f7ff 60%, #e8fff4 100%);">
#   <h1 style="margin:0 0 8px; font-size: 2rem;">
#     👋 Welcome to Math 105 Lab 4!
#   </h1>
#
#   <div style="margin-top:16px; padding:12px 14px; border:1px dashed #94a3b8; border-radius:12px; background:#fff;">
#     <strong>Today’s mission:</strong> More practice functions and plotting in Python.</div>
#
#   <div style="margin-top:14p

# %% [markdown]
# ### Exercise #1
#
# Create a lambda function to plot the exponential relationship from Exercise 1.6.11 in the Guided Notes.

# %%
#code here

# %% [markdown]
# ### Exercise #2
#
# Produce a plot showing the data and the model from Exercise 1.6.11 on the same graph.

# %%
# Import the plotting library
import matplotlib.pyplot as plt
import numpy as np

# Enter the data
t = [0, 1, 2, 3, 4, 5]

U = [15.0, 22.7, 34.9, 53.6, 81.5, 121.9]

# Define the model
U_func = lambda t: ???

# Make an array of input values
# t_eval = np.linspace(start, end, number of points)
t_eval = np.linspace(???)

# Evaluate the models at each value of t in the array
U_eval = [U_func(x) for x in t_eval]

# Create the graph
plt.figure(figsize=(8, 5))

# Plot the functions
#make the function a black dashed line
plt.plot(???)

# Plot the data
# Make the data red x's. Hint: use marker="x"
plt.scatter(???)

# Add labels
plt.legend()

# Change the horizontal and vertical axis limits
plt.xlim(???)
plt.ylim(???)

# Add labels and a title
plt.xlabel("Distance")
plt.ylabel("Happiness")

plt.show()

# %% [markdown]
# ### Exercise 3
# Use Python to complete Exercise 1.6.12 in the Guided Notes.

# %%
# Import the plotting library
import matplotlib.pyplot as plt
import numpy as np

# Enter the parameters
T_initial = ???
T_room = ???
r = ???

# Define the temperature model
T = lambda t: ???

# Find the temperature when t = 0
???

# Find the temperature after t = 60
???

# Make a plot of the function
# Create a list of input values from 0 to 180 minutes
#t = np.linspace(start,end,number evaluation points)
t = np.linspace(???)

# Calculate the temperature at each input value
temperature = [T(x) for x in t]

# Plot the model
plt.plot(???)

# Set x and y axis
plt.xlim([0,300])
plt.ylim([0,200])

# Label the graph
plt.xlabel("Time (minutes)")
plt.ylabel("Temperature (°F)")
plt.title("Temperature of Coffee Over Time")

# Add a grid
plt.grid()

plt.show()

# %% [markdown]
# ### Exercise 4
# Use your code above to complete Exercise 1.6.13 in the Guided Notes.

# %% [markdown]
# <div style="font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, 'Helvetica Neue', Arial; padding: 20px; border-radius: 16px; box-shadow: 0 10px 25px rgba(0,0,0,.08); background: linear-gradient(135deg,#fff 0%, #f0f7ff 60%, #e8fff4 100%);">
#   <h1 style="margin:0 0 8px; font-size: 2rem;">
#     👋 Welcome to Math 105 Lab 8!
#   </h1>
#
#   <div style="margin-top:16px; padding:12px 14px; border:1px dashed #94a3b8; border-radius:12px; background:#fff;">
#     <strong>Today’s mission:</strong> Use sympy to evaluate the limit from class and plot derivatives in Python.
#   </div>
# </div>

# %% [markdown]
# ### Using Python to Evaluate a Limit
# Let's see how Python can help us evaluate the limit from class:
# $$P'(t_0) = \lim_{\Delta t \to 0} \frac{P(t_0+\Delta t)-P(t_0)}{\Delta t}$$
# where $P(t) = -4t^2+40t$.

# %%
import sympy as sp

# Define symbols
delta_t, t0 = sp.symbols('???')

# Define the function symbolically
P = lambda t: ???

# Average rate of change over [t0, t0 + delta_t]
average_rate = (P(t0 + delta_t) - P(t0)) / delta_t

# Simplify the average rate of change
simplified_rate = sp.simplify(average_rate)

# What happens as delta_t approaches 0?
limit = simplified_rate.subs(delta_t, ???)

print("\n Derivative at t0:",limit)

# %% [markdown]
# ### Exercise 1:
#
# Plot the function in Exercise 4.2.1 of the Guided Notes from $[-1.5,1.5]$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the graph
fig, ax = plt.subplots(figsize=(10,8))

# Define array of input values
t = np.linspace(???)

# Define f(t)
f = lambda t: ???

ax.plot(???)

######## Extras #######################
plt.grid()

# Move axes to the origin
ax.spines["left"].set_position("zero")
ax.spines["bottom"].set_position("zero")

# Hide the other two borders
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")

# Put tick marks on the axes
ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")

plt.show()

# %% [markdown]
# ### Exercise 2:
#
# Use the code below to fill in the table.

# %%
import numpy as np

###### Derivative Function, DO NOT EDIT ##########
f_prime = lambda t:6*t**7-.3*5*t**4+4*.1*t**3-3*2*t
####################################################

###### Define inputs, EDIT THIS #####
inputs = [???]

for t in inputs:
    print("f'({}) = {}".format(???))

# %% [markdown]
# ### Exercise 3:
# Plot each point $(t,f'(t))$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the graph
fig, ax = plt.subplots(figsize=(10,8))

#### Info to plot f, DO NOT EDIT ###############
t = np.linspace(-1.5,1.5,1000)
f = lambda t: t**6-0.3*t**5 + 0.1*t**4-3*t**2 + 1
ax.plot(t,f(t))
################################################

# Info to plot f'
inputs = [-1,-.75,-.5,0,.5,.75,1]
outputs = []

for t in inputs:
    ax.scatter(???)#(input point, output point), this will make dots
    outputs.append(????)#collect output values in loop to use as array

ax.plot(???)#connect dots with a line

######## Extras #######################
plt.grid()

# Move axes to the origin
ax.spines["left"].set_position("zero")
ax.spines["bottom"].set_position("zero")

# Hide the other two borders
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")

# Put tick marks on the axes
ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")

plt.show()

# %% [markdown]
# ### Exercise 3:
# Use the code below to plot the tanget line at a point.
#
# -The general formula for a line is:
#
# -The slope of the tanget line is equal to:
#
# -To get formula for the tangent line:

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the symbolic variable
t = sp.symbols("???")

# Define the function
f = ???

# Compute the derivative
f_prime = sp.diff(f, t)

# Convert symbolic expressions into numerical functions
############### DO NOT EDIT ############################
f_function = sp.lambdify(t, f, "numpy")
f_prime_function = sp.lambdify(t, f_prime, "numpy")

# Values for plotting
t = np.linspace(-1.5, 1.5, 1000)

# Creat figure
fig, ax = plt.subplots(figsize=(9, 6))

# Plot f(t)
ax.plot(t, f_function(t), label="f(t)", linewidth=3)

# Plot f'(t)
ax.plot(t, f_prime_function(t), label="f'(t)", linewidth=3)
##########################################################

# Tangent-line equation
t0 = ???
y0 = f_function(???)
slope = f_prime_function(???)
f_tan = lambda t: ???

# Plot tangent line at a point
tangent_inputs = ???
tangent_outputs = ???
# plot the tangent line
ax.plot(???,???,linestyle="--",linewidth = 2,label=f"Tangent at t = {t0}")

# Mark the point of tangency
ax.scatter(???, ???, color="black")

######## Extras #######################
plt.grid()

# Make the axes meet at (0, 0)
ax.spines["left"].set_position("zero")
ax.spines["bottom"].set_position("zero")
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")

ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-4, 6)
ax.grid(alpha=0.3)
ax.legend()

plt.show()

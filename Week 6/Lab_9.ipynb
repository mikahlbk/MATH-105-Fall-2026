# %% [markdown]
# <div style="font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, 'Helvetica Neue', Arial; padding: 20px; border-radius: 16px; box-shadow: 0 10px 25px rgba(0,0,0,.08); background: linear-gradient(135deg,#fff 0%, #f0f7ff 60%, #e8fff4 100%);">
#   <h1 style="margin:0 0 8px; font-size: 2rem;">
#     👋 Welcome to Math 105 Lab 9!
#   </h1>
#
#   <div style="margin-top:16px; padding:12px 14px; border:1px dashed #94a3b8; border-radius:12px; background:#fff;">
#     <strong>Today’s mission:</strong> Write code to complete exercise 4.3.1.
#   </div>
# </div>

# %% [markdown]
# ### When Derivatives Don't Exist
#
# We often use this definition of the derivative that relies on $h$ instead of $\Delta t$:
# $$f'(x) = \lim_{h \to 0} \frac{f(x+h)-f(x)}{h}$$
#
# Here we interpret $h$ as the change in the input value over some interval. So the point of interest (the left endpoint of the interval) is $a$, and the right endpoint of the interval is $b=a+h$, so that $h=b-a$.
#
# You are going to write code to fill in the table for Exercise 4.3.1 on page 112 of the Guided Notes.

# %%
# Step 1: Define a variable called a and assign it the value of 
# the point of interest



# Step 2: Define a lambda function called f that computes 
# the output values of the function in question



# Step 3: Define a lambda function called A that computes the
# average rate of change over the interval [a, a+h].
# The function A should have two inputs: a and h.



# Step 4: Create a list of h-values



# Step 5: Loop through the h-values. For each value of h,
# compute the slope of the secant line over [a, a+h]
# and print the result.

# Your output should have the form:
# When h = #, the slope of the secant line is m = #

# %% [markdown]
# ### If you finish this, work on Exercise 4.3.2 on the next page of the Guided Notes.
